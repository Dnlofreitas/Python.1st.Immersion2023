# %% [markdown]
# DANILO FREITAS PYTHON START

# %%
print ("ola mundo")
# Out:
# ola mundo

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# MATHS

# %%
# soma de 2 números
1+1
# Out:
# 2

# %%
# Multiplicação
5 * 2
# Out:
# 10

# %%
# Potencia
5**2
# Out:
# 25

# %%
#Divisao
10 /2
# Out:
# 5.0

# %% [markdown]
# # Variables
#
# ```
# # Isto está formatado como código
# ```

# %%
a = 4
b = 6

# %%
a+b
# Out:
# 10

# %%
print (a)
# Out:
# 4

# %%
print (b)
# Out:
# 6

# %%
Nome = "Fernanda"

# %%
print (Nome)
# Out:
# Fernanda

# %%
# Verificando o tipo da variável idade

# %%
type(Nome)
# Out:
# str

# %% [markdown]
# Managing Strings ( variables that storages Texts )

# %%
textodan = "Estou apredendo Python"

# %%
textodan[0:100]
# Out:
# 'Estou apredendo Python'

# %%
textodan[0:10]
# Out:
# 'Estou apre'

# %%
# textodan.upper() textodan.lower() textodan.capitalize() textodan.split() frase = textodan.replace("análise", "Ciência")
textodan.upper()
# Out:
# 'ESTOU APREDENDO PYTHON'

# %%
textodan.lower()
# Out:
# 'estou apredendo python'

# %%
textodan.capitalize()
# Out:
# 'Estou apredendo python'

# %%
textodan.split()
# Out:
# ['Estou', 'apredendo', 'Python']

# %% [markdown]
# DATA STRUCTURE

# %%
# Listas
# Sintaxe para criar listas em Python []
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["Cachorro", "Gato", 12345]
animais
# Out:
# ['Cachorro', 'Gato', 12345]

# %%
animais[2]
# Out:
# 12345

# %%
"Gato" in animais
# Out:
# True

# %%
#PUT LIST IN ORDER
lista = [10,5,30,100,80]
lista
# Out:
# [10, 5, 30, 100, 80]

# %%
lista.sort()

# %%
lista
# Out:
# [5, 10, 30, 80, 100]

# %%
max(lista)
# Out:
# 100

# %%
min(lista)
# Out:
# 5

# %% [markdown]
# # Tuplas

# %%
# As tuplas usam o parêntese como sintaxe
tp = ("banana", "Maçã", 20)
tp
# Out:
# ('banana', 'Maçã', 20)

# %%
tp
# Out:
# ('banana', 'Maçã', 20)

# %%
# Para criar um dicionário utilizamos as {}
# Dicionários trabalham com o conceito de chave e valor
dc = {"Maçã":20, "Banana":15, "Laranja":5}
dc
# Out:
# {'Maçã': 20, 'Banana': 15, 'Laranja': 5}

# %%
dc
# Out:
# {'Maçã': 20, 'Banana': 15, 'Laranja': 5}

# %%
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Laranja'])

# %% [markdown]
# CONDITIONS

# %%
if idade == 18:
  print("Você é maior de idade")
else:
  print("Você não tem 18 anos")
# Out:
# Você é maior de idade

# %%
idade = 25
if idade < 18:
  print("Você é menor de idade")
elif idade >=18 and idade < 65:
  print("Você é adulto")
else:
  print("Você é idoso")
# Out:
# Você é adulto

# %%
nome = "Fernanda"
if 10 > 20 or nome == "Fernanda":
  print("Olá Fernanda")
else:
  print("Você não é Fernanda")
# Out:
# Olá Fernanda

# %%
if 10 > 20 and nome == "Fernanda":
  print("Olá Fernanda")
else:
  print("Você não é Fernanda")
# Out:
# Você não é Fernanda

# %% [markdown]
# l o o p s

# %%
#LOOP#;
for i  in ["Audi", "Ferrari", "Fusca"]:
  print(i)
# Out:
# Audi
# Ferrari
# Fusca

# %%
for carros in ["Ferrari", "Audi", "Fusca"]:
  print(carros)
# Out:
# Ferrari
# Audi
# Fusca

# %% [markdown]
# F U N C O E S

# %%
def saudacao():
  print("Olá, Seja bem vindo(a)!!")

# %%
saudacao()
# Out:
# Olá, Seja bem vindo(a)!!

# %%
def hello(nome):
  print("Olá", nome)

# %%
hello("Fernanda")
# Out:
# Olá Fernanda

# %%
def soma(n1,n2):
  return (f"A soma dos 2 números é: {n1 + n2}")

# %%
soma(10,500)
# Out:
# 'A soma dos 2 números é: 510'

# %%
def imc():
  peso = float(input("Qual o seu peso?"))
  altura = float(input("Qual a sua altura?"))

  imc = peso/altura**2
  return imc

# %%
imc()
# Out:
# Qual o seu peso?74
# Qual a sua altura?1.70
# 25.605536332179934

# %%
1+1
# Out:
# 2
